# %% [markdown]
# # Step 1: Install Packages

# %%
# %%capture #This command supresses output of the console. Delete it while installing to see console info.
conda install pandas
# Out:
# UsageError: unrecognized arguments: command supresses output of the console. Delete it while installing to see console info.

# %%
# %%capture
conda install matplotlib
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-f84a725ceecb> in <module>
# ----> 1 get_ipython().run_line_magic('conda', 'install matplotlib')
#
# /usr/local/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2315                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2316             with self.builtin_trap:
# -> 2317                 result = fn(*args, **kwargs)
#    2318             return result
#    2319
#
# <decorator-gen-107> in conda(self, line)
#
# /usr/local/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.7/site-packages/IPython/core/magics/packaging.py in conda(self, line)
#      77         """
#      78         if not _is_conda_environment():
# ---> 79             raise ValueError("The python kernel does not appear to be a conda environment.  "
#      80                              "Please use ``%pip install`` instead.")
#      81
#
# ValueError: The python kernel does not appear to be a conda environment.  Please use ``%pip install`` instead.

# %%
# %%capture
conda install numpy

# %%
import os
import sys
sys.executable

# %%
#where python locates imported packages:
sys.path
# Out:
# ['/Users/rihan/Documents/Work/covid/covidinnovations/data',
#  '/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python37.zip',
#  '/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7',
#  '/usr/local/Cellar/python/3.7.4/Frameworks/Python.framework/Versions/3.7/lib/python3.7/lib-dynload',
#  '',
#  '/usr/local/lib/python3.7/site-packages',
#  '/usr/local/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/rihan/.ipython']

# %%
#where python found imported package
import numpy
numpy.__path__
# Out:
# ['/usr/local/lib/python3.7/site-packages/numpy']

# %%
# Airtable python wrapper api: https://github.com/gtalarico/airtable-python-wrapper
# Documentation: https://airtable-python-wrapper.readthedocs.io/en/master/api.html#class-api

# On best practices for installing packages into jupyter notebook?... : https://jakevdp.github.io/blog/2017/12/05/installing-python-packages-from-jupyter/
# for installing pip packages:
#! /home/[user]/miniconda3/bin/python -m pip install airtable-python-wrapper

# or just use the basic:
! python -m pip3 install airtable-python-wrapper
# Out:
# /usr/bin/python: No module named pip3

# %% [markdown]
# # Step 2: Airtable Auto Import

# %%
from airtable import Airtable

#airtable.__path__

#Generate key from: https://airtable.com/account
#Our base key: appl4hiR4DMyx28Bg

base_key = 'appl4hiR4DMyx28Bg'
table_name = 'Tenders (Published)'
api_key = 'keyZ09GT0FWjXWkX4'
tenders_published = Airtable(base_key, table_name, api_key)

categories = Airtable(base_key, "Categories", api_key)

print(tenders_published)
print(categories)
# Out:
# <Airtable table:Tenders (Published)>
# <Airtable table:Categories>

# %%
# Get All data with Max Records
tenders_records = tenders_published.get_all(maxRecords=20)

categories_records = categories.get_all(maxRecords=20)

tenders_records
#categories_records
# Out:
# [{'id': 'rec06VJwIRnUsW3XH',
#   'fields': {'Name': 'COVID-19 Response Team',
#    'Categories': ['recIq8hBU4RbxR42y',
#     'rec0XJtb00Csoh3CT',
#     'recj4TMhOU9ieeweU',
#     'recQCO0OJC04Cg0aZ',
#     'recI5ZRtTNRaZm80W',
#     'rec10jFunep6i7LND',
#     'recWQc2ta6gw3MFoO',
#     'recx3OdNvu7vqHLrL',
#     'rec9GaNTHXsfeq8UH',
#     'recONh9EvkVDp2zKQ',
#     'recMZ54t74nfcctvr',
#     'recc8FTZUD8j9obGa'],
#    'Organization Logo': [{'id': 'attppHQ5SVbIKtSDn',
#      'url': 'https://dl.airtable.com/.attachments/7805659475948cfcc40cd09f144c7ffc/d1c732f7/download12.png',
#      'filename': 'download (12).png',
#      'size': 3565,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/67191d1f5474dce249ee0fe3f336bec1/e132b01e',
#        'width': 36,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/ba6189441fdcd6a8fb184b239ee6c8dc/846c5f8c',
#        'width': 225,
#        'height': 225},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/7125ade806cfa2dcbd7600f9cba5f623/6df58384',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-12-31',
#    'Official URL': 'https://www.afwerx.af.mil/coronavirus.html',
#    'Issued': '2020-03-01',
#    'Issuance country': ['recU6gnws8yPUAlHm'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-03-28T15:44:00.000Z',
#    'ID': 35,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'support@afwerx.af.mil',
#    'Organization': 'U.S. Air Force',
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-03-29T13:51:43.000Z'},
#  {'id': 'rec097ng8PrTjC6PQ',
#   'fields': {'Name': 'CcHUB: Funding and Design Support for COVID-19 Projects',
#    'Categories': ['recI5ZRtTNRaZm80W',
#     'recWQc2ta6gw3MFoO',
#     'recj4TMhOU9ieeweU',
#     'rec10jFunep6i7LND',
#     'recQCO0OJC04Cg0aZ'],
#    'Organization Logo': [{'id': 'att1oHIJ5bNw6DC30',
#      'url': 'https://dl.airtable.com/.attachments/9d1aa3627a3eb043c35ddcc9d4236af3/798c0718/logo.png',
#      'filename': 'logo.png',
#      'size': 11688,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/3d14e072023ce74947da2909636381a2/03ef0750',
#        'width': 145,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/493052929b29f6d82f57de1059672125/1ace6ea0',
#        'width': 784,
#        'height': 195},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/83b4dc894d6b5794b12f68746f2f3bd0/8964ada0',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-12-31',
#    'Official URL': 'https://cchubnigeria.com/call-for-projects-funding-and-design-support-for-covid-19-projects/',
#    'Issued': '2020-03-01',
#    'Issuance country': ['recry9M8YByJ3ay9z'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-03-27T19:47:00.000Z',
#    'ID': 29,
#    'Input by': 'Natali Souza',
#    'Organization': 'Co-Creation Hub',
#    'Organization Type': 'Private Company'},
#   'createdTime': '2020-03-28T00:01:57.000Z'},
#  {'id': 'rec0YK8cWEHNQkzn3',
#   'fields': {'Name': 'Challenge Covid-19',
#    'Categories': ['recQCO0OJC04Cg0aZ',
#     'rec10jFunep6i7LND',
#     'recj4TMhOU9ieeweU'],
#    'Organization Logo': [{'id': 'attNyZ3u47aCEXBuG',
#      'url': 'https://dl.airtable.com/.attachments/000dd8f3012550b6a5dbcc74879740d2/0a3add1f/images1.jpg',
#      'filename': 'images (1).jpg',
#      'size': 9828,
#      'type': 'image/jpeg',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/9c697dedec3082d237658550f02234a6/8db66881',
#        'width': 36,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/9f4ba304e939997ba437ae820d4ba5a4/c610152a',
#        'width': 225,
#        'height': 224},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/f22d6f1eec905035464dc4882b52ceb5/69c761ae',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-05-03',
#    'Official URL': 'https://sites.google.com/view/challengepanama',
#    'Issued': '2020-04-22',
#    'Issuance country': ['recNjRjraKVnsyLRC'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-04-24T11:47:00.000Z',
#    'Notes': 'https://docs.google.com/document/d/1IWmtgRno81ymY677tsbeX16PWF_1J4hNLB1Wrl7n1oA/edit#',
#    'ID': 115,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'Alejandro Carbonell: acarbonell@cdspanama.org',
#    'Organization': 'Alianza para el Emprendimiento e Innovacion Panamá',
#    'Organization Type': 'Private Company'},
#   'createdTime': '2020-04-26T00:41:44.000Z'},
#  {'id': 'rec0oUzZetEKdsAs7',
#   'fields': {'Name': 'Invitation of technology proposals for fighting COVID 19',
#    'Categories': ['rec10jFunep6i7LND',
#     'rec0XJtb00Csoh3CT',
#     'recIq8hBU4RbxR42y',
#     'recMZ54t74nfcctvr',
#     'recI5ZRtTNRaZm80W'],
#    'Organization Logo': [{'id': 'att2yPDAO8zM2Wg4t',
#      'url': 'https://dl.airtable.com/.attachments/eeeef66434e1468d251b6feb744b4d66/99cf42c6/images.png',
#      'filename': 'images.png',
#      'size': 7354,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/7f465f6021e37792509f125a34a92736/dacaeea3',
#        'width': 36,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/06329c5f1466615225b57ce90e23c75b/9176e2c5',
#        'width': 226,
#        'height': 223},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/99a3953ee114e6978ab311cbb3a1bc4e/75064961',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-04-30',
#    'Official URL': 'https://dst.gov.in/pressrelease/tdb-invites-technology-proposals-fighting-covid-19',
#    'Issued': '2020-03-21',
#    'Issuance country': ['rectx8xceFl3DDiVX'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'National',
#    'Entry Timestamp': '2020-03-26T21:55:00.000Z',
#    'Notes': 'http://tdb.gov.in/wp-content/uploads/2020/03/TDB-advt_16x25-Eng-New2.pdf',
#    'ID': 21,
#    'Input by': 'Musadiq Ali ',
#    'Organizer Contact': 'Telephone: +91-11-26562122/25/33/44, 26567373, 26962819',
#    'Organization': 'Technology Development Board',
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-03-26T22:00:14.000Z'},
#  {'id': 'rec2JvyJBepoGda6L',
#   'fields': {'Name': 'Call for innovations who can offer a response to the COVID-19 pandemic',
#    'Categories': ['recWQc2ta6gw3MFoO',
#     'recIq8hBU4RbxR42y',
#     'rec0XJtb00Csoh3CT',
#     'rec9GaNTHXsfeq8UH',
#     'recEwfTiy7301HPv3'],
#    'Organization Logo': [{'id': 'attpviHODDAYjAbbJ',
#      'url': 'https://dl.airtable.com/.attachments/742835fff8741cd6b4fe6310c2cbc78b/a7b38210/download16.png',
#      'filename': 'download (16).png',
#      'size': 7346,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/a17413ac7aca881d8124be86ecfd76a7/451d5370',
#        'width': 82,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/075a1f64c21f9e4acfd8794b029b7932/b87a65dd',
#        'width': 338,
#        'height': 149},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/d9d4baa5f75ed41431f1067959b2de8c/09c9810a',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-12-31',
#    'Official URL': 'http://www.china.enrichcentres.eu/news/covid-19-response-call-financial-investment-opportunities',
#    'Issued': '2020-03-01',
#    'Issuance country': ['recZrQH3kELDGwfGA'],
#    'Budget (Detail)': '$541,405 upwards',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-04-21T11:18:00.000Z',
#    'Notes': 'Other categories: AgriTech',
#    'ID': 106,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'blakemore@steinbeis-europa.de',
#    'Organization': 'European Network of Research and Innovation Centres and Hubs, China',
#    'Total Budget (USD, Estimated)': 2707025,
#    'Organization Type': 'Private Company'},
#   'createdTime': '2020-04-26T00:41:44.000Z'},
#  {'id': 'rec2nlNNgzNfA1Him',
#   'fields': {'Name': 'AMable Call for Solution Ideas to COVID-19 challenges ',
#    'Categories': ['rec10jFunep6i7LND', 'recWQc2ta6gw3MFoO'],
#    'Organization Logo': [{'id': 'attLlp79qVKKXS01V',
#      'url': 'https://dl.airtable.com/.attachments/3a9aac49c6963fe62309dab6c37d2d1d/3185c3bb/amable.png',
#      'filename': 'amable.png',
#      'size': 23952,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/51beaf5a969c03f91ce4c05bd5470779/c7cc15b3',
#        'width': 126,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/157eceaf18cbdc1152f64990beb88a96/4eeab093',
#        'width': 300,
#        'height': 86},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/b76000441c4598ab342747183edf6e9e/6e1ddf7c',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-10-01',
#    'Official URL': 'https://www.amable.eu/calls/call-for-proposals',
#    'Issued': '2020-04-01',
#    'Issuance country': ['recPLWNLCURrjmfEd'],
#    'Budget (Detail)': '382,819',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-04-10T11:49:00.000Z',
#    'Notes': 'https://www.amable.eu/fileadmin/amable/documents/call-for-proposals-covid19/AMable_COVID-19_GuideForApplicants_TH_v0100.pdf',
#    'ID': 80,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'covid-19@amable.eu',
#    'Organization': 'AMable',
#    'Total Budget (USD, Estimated)': 382819,
#    'Organization Type': 'Other (Detail in comments)'},
#   'createdTime': '2020-04-12T15:04:56.000Z'},
#  {'id': 'rec2vCgZNnJ1dwvlw',
#   'fields': {'Name': 'Covid-19 Resilience Innovation Project Support',
#    'Categories': ['recWQc2ta6gw3MFoO',
#     'rec10jFunep6i7LND',
#     'recMZ54t74nfcctvr'],
#    'Organization Logo': [{'id': 'attNS8yaX24IaP8F4',
#      'url': 'https://dl.airtable.com/.attachments/70f042d246d4fc7156b406c5b36f4bdd/9dc86b86/wales_gov.png',
#      'filename': 'wales_gov.png',
#      'size': 3496,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/4f6a3294e3a3aae8d090596c1fd5d3d5/0b4da349',
#        'width': 141,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/8757b854af9e34849695fea960af470b/2a8b846a',
#        'width': 141,
#        'height': 36},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/d94c8b078d0af6deb540b5e97da9a2a8/8f9e57fa',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-12-31',
#    'Official URL': 'https://businesswales.gov.wales/expertisewales/covid-19-resilience-innovation-project-support',
#    'Issued': '2020-03-01',
#    'Issuance country': ['recGdqpTXWbgK48CN'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'National',
#    'Entry Timestamp': '2020-04-16T11:04:00.000Z',
#    'ID': 87,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'To get started you can contact our team on 03000 250 243 or Email SMARTCymru@gov.wales',
#    'Organization': 'Welsh Government',
#    'Total Budget (USD, Estimated)': 0,
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-04-26T00:41:40.000Z'},
#  {'id': 'rec3BNc4RXLLfq5iE',
#   'fields': {'Name': 'COVID-19 Solutions in Digital Health',
#    'Categories': ['recIq8hBU4RbxR42y',
#     'recWQc2ta6gw3MFoO',
#     'rec0XJtb00Csoh3CT',
#     'rec9GaNTHXsfeq8UH',
#     'recQCO0OJC04Cg0aZ'],
#    'Organization Logo': [{'id': 'attAPMf2WR4fb9Z6s',
#      'url': 'https://dl.airtable.com/.attachments/32c65fc3fd33ee741f9508c21c085c38/eb7741c6/download6.png',
#      'filename': 'download (6).png',
#      'size': 5357,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/239b28765b1aeeb7d75df2afa658d53b/f72717e9',
#        'width': 36,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/bd4085fe815f7689b35e560ada1fef9d/84fd2e4c',
#        'width': 225,
#        'height': 225},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/57861d7af7ee79a3ac6873a790ec226c/3ebd97fd',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-04-14',
#    'Official URL': 'https://eithealth.eu/opportunity/headstart-funding-programme/',
#    'Issued': '2020-03-31',
#    'Issuance country': ['recPLWNLCURrjmfEd'],
#    'Budget (Detail)': 'Up to 54,030 per solution. Total budget is best guess estimate by covidtenders. ',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-04-03T10:43:00.000Z',
#    'Notes': 'https://eithealth.eu/wp-content/uploads/2020/03/Headstart_Guide_Addendum_COVID-19_Solutions-1.pdf',
#    'ID': 62,
#    'Input by': 'Natali Souza',
#    'Organization': 'EIT Health',
#    'Total Budget (USD, Estimated)': 270150,
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-04-04T16:41:37.000Z'},
#  {'id': 'rec3Hnse2ey2FjP6n',
#   'fields': {'Name': 'Call for Proposals for Projects in the Development, Piloting and Demonstration stages to cope with the Coronavirus',
#    'Categories': ['rec0XJtb00Csoh3CT',
#     'recj4TMhOU9ieeweU',
#     'recx3OdNvu7vqHLrL',
#     'rec9GaNTHXsfeq8UH',
#     'recWQc2ta6gw3MFoO',
#     'recI5ZRtTNRaZm80W',
#     'recQCO0OJC04Cg0aZ',
#     'recc8FTZUD8j9obGa'],
#    'Organization Logo': [{'id': 'attTi4Nvg3WYbIXzi',
#      'url': 'https://dl.airtable.com/.attachments/213e854ab4299e6691f9a2eb812ad2d7/3db6eb7c/download16.png',
#      'filename': 'download (16).png',
#      'size': 3575,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/849d179b098dd8567580305575cf5daf/c4a298d2',
#        'width': 90,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/6c3846e7062946dda825f4be2ec6f899/11f9be11',
#        'width': 355,
#        'height': 142},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/59a25ce51e7eb4807061c08bf02d1fed/22038bae',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-04-07',
#    'Official URL': 'https://innovationisrael.org.il/en/opencall/piloting-and-demo-stages-to-fight-coronavirus',
#    'Issued': '2020-03-26',
#    'Issuance country': ['recwm7U7duodbdwD1'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'National',
#    'Entry Timestamp': '2020-03-31T11:29:00.000Z',
#    'ID': 42,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'Growth@innovationisrael.org.il',
#    'Organization': 'Israel Innovation Authority',
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-04-01T18:04:47.000Z'},
#  {'id': 'rec4twgOfPTyBn8NW',
#   'fields': {'Name': 'COVID-19 Extraordinary Call for Proposals 2020',
#    'Categories': ['recx3OdNvu7vqHLrL',
#     'recIq8hBU4RbxR42y',
#     'recj4TMhOU9ieeweU',
#     'recONh9EvkVDp2zKQ',
#     'recWQc2ta6gw3MFoO',
#     'recI5ZRtTNRaZm80W',
#     'recQCO0OJC04Cg0aZ'],
#    'Organization Logo': [{'id': 'atthfMV8J5m38Zme8',
#      'url': 'https://dl.airtable.com/.attachments/1367e365f2b8e1cdecf2bf256fbd9bf0/d2b82696/download18.png',
#      'filename': 'download (18).png',
#      'size': 5620,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/4f35c3efdce4977760db18272426d7cc/777edddd',
#        'width': 36,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/cc0a27101cbaf82ffa0c3ca5207f96aa/0c861bda',
#        'width': 225,
#        'height': 225},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/c5cb86a0de63730926790faa70cb24ce/7394bbdb',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-04-09',
#    'Official URL': 'https://www.cei.int/news/8809/covid-19-extraordinary-call-for-proposals-launched-600000-eur-for-projects-in-field-of-healthcare',
#    'Issued': '2020-03-27',
#    'Issuance country': ['recPLWNLCURrjmfEd'],
#    'Budget (Detail)': '658,002',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-03-31T15:01:00.000Z',
#    'Notes': 'https://www.cei.int/sites/default/files/2020-03/CEI%20Extraordinary%20Call%202020%20F.pdf',
#    'ID': 47,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'applications@cei.int',
#    'Organization': 'Central European Initiative',
#    'Total Budget (USD, Estimated)': 658002,
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-04-01T18:04:47.000Z'},
#  {'id': 'rec57KBQLFUD3aHfm',
#   'fields': {'Name': "Santa Catarina's Business Fund for Articulated Reaction Against Coronavirus ",
#    'Categories': ['rec10jFunep6i7LND',
#     'rec0XJtb00Csoh3CT',
#     'recMZ54t74nfcctvr',
#     'recQCO0OJC04Cg0aZ',
#     'recONh9EvkVDp2zKQ',
#     'recj4TMhOU9ieeweU',
#     'recWQc2ta6gw3MFoO'],
#    'Organization Logo': [{'id': 'attYFa32t769v642c',
#      'url': 'https://dl.airtable.com/.attachments/68ad3b58d42bf81bde571a0ea74c2a1f/48408a52/fera.png',
#      'filename': 'fera.png',
#      'size': 20912,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/12e9dd745d0d19b1a9f6700dbc08d06d/0a104e7d',
#        'width': 53,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/7189fd095891716aad147b14b9dd9e29/ca3b883a',
#        'width': 167,
#        'height': 114},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/cadc2bb912cff1f2a96c9e4b1d54d677/cd2737ea',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-12-31',
#    'Official URL': 'https://www.observatoriofiesc.com.br/ferasc',
#    'Issued': '2020-03-24',
#    'Issuance country': ['rec0dCotboTd3uHn8'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'National',
#    'Entry Timestamp': '2020-03-27T16:37:00.000Z',
#    'ID': 27,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'Maicon Lacerda, ferasc_projeto@fiesc.com.br',
#    'Organization': 'Federação das Indústrias do Estado de Santa Catarina',
#    'Organization Type': 'Private Company'},
#   'createdTime': '2020-03-28T00:01:57.000Z'},
#  {'id': 'rec80I1CE8PuAFNpb',
#   'fields': {'Name': 'Botswana Innovation Fund Call for Applications',
#    'Categories': ['recIq8hBU4RbxR42y',
#     'recQCO0OJC04Cg0aZ',
#     'rec10jFunep6i7LND',
#     'recj4TMhOU9ieeweU',
#     'rec0XJtb00Csoh3CT',
#     'recI5ZRtTNRaZm80W',
#     'recWQc2ta6gw3MFoO'],
#    'Organization Logo': [{'id': 'attnTk3Hr2AnQf0aS',
#      'url': 'https://dl.airtable.com/.attachments/a36ebc8b9a51f57d0dad94b83c778bcb/7332ae15/images.jpg',
#      'filename': 'images.jpg',
#      'size': 8587,
#      'type': 'image/jpeg',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/f8feb63cf0296d7487fc8b710fd3e1f2/2133a43e',
#        'width': 62,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/28400af501a43f53313aba6275560745/4947e977',
#        'width': 294,
#        'height': 171},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/6ea16b570f41782d0556be017dad8dd6/4cfae2ca',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-05-01',
#    'Official URL': 'https://form.jotform.com/innovationfund/application',
#    'Issued': '2020-04-18',
#    'Issuance country': ['rec3Z5GtXK7s5Ebvh'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'National',
#    'Entry Timestamp': '2020-04-23T14:29:00.000Z',
#    'Notes': 'https://pbs.twimg.com/media/EV4xgjAXgAA3qjO?format=jpg&name=4096x4096',
#    'ID': 113,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'innovationfund@bih.co.bw; cc procurement@bih.co.bw',
#    'Organization': 'Botswana Innovation Hub',
#    'Organization Type': 'Private Company'},
#   'createdTime': '2020-04-26T00:41:44.000Z'},
#  {'id': 'rec8ZL2bN89en1d9R',
#   'fields': {'Name': 'Mining companies unite to face the challenges of Covid-19 together',
#    'Categories': ['recIq8hBU4RbxR42y',
#     'rec0XJtb00Csoh3CT',
#     'recx3OdNvu7vqHLrL',
#     'recMZ54t74nfcctvr',
#     'recI5ZRtTNRaZm80W',
#     'recuZ68TmTG5jWEvg',
#     'recj4TMhOU9ieeweU',
#     'recc8FTZUD8j9obGa',
#     'recWQc2ta6gw3MFoO'],
#    'Organization Logo': [{'id': 'attpTOSaQ6iqCDGyM',
#      'url': 'https://dl.airtable.com/.attachments/6a0d7865e9f666725440e796e2c75c0b/b34f2be5/Semttulo.png',
#      'filename': 'Sem título.png',
#      'size': 21659,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/e4a2b114c0d1018f53dc065eba5922ac/8ed65973',
#        'width': 158,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/7e0a1bd7f790b3a8c476dbf38ccb4bc9/c6278088',
#        'width': 372,
#        'height': 85},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/4b5779e0233ee285e4571a902f1fad75/eb8985f6',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-04-23',
#    'Official URL': 'https://expandemineria.cl/desafio/desafios-covid-19/#beneficios',
#    'Issued': '2020-04-09',
#    'Issuance country': ['recDqWXc2i3JVmFnd'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-04-17T10:50:00.000Z',
#    'ID': 95,
#    'Input by': 'Natali Souza',
#    'Organization': 'Antofagasta Minerals, Angloamerican, BHP, Codelco, Mantos Copper and Teck',
#    'Total Budget (USD, Estimated)': 0,
#    'Organization Type': 'Private Company'},
#   'createdTime': '2020-04-26T00:41:44.000Z'},
#  {'id': 'rec9nJnmIzKAkzzNw',
#   'fields': {'Name': 'Coronavirus (Covid-19) Therapeutics: £10 Million Call For Rapid Deployment',
#    'Categories': ['rec9GaNTHXsfeq8UH'],
#    'Organization Logo': [{'id': 'attOHpO4CLiGBND6P',
#      'url': 'https://dl.airtable.com/.attachments/d793718a5011110ba501cb245d6df143/e81e04a9/01.png',
#      'filename': '0 (1).png',
#      'size': 10449,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/ba546551a0f40b719f5277cf7296e9bc/f62a8e17',
#        'width': 36,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/50463742d67dbe1ff857894314cd0f77/197d2f72',
#        'width': 200,
#        'height': 200},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/f1be16a39427b2725f53ab49afa3b008/789fa440',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-04-06',
#    'Official URL': 'https://www.lifearc.org/funding/covid-19/covid-19-funding/',
#    'Issued': '2020-03-20',
#    'Issuance country': ['recVHZtLbdvDmSSYd'],
#    'Budget (Detail)': '12,466,150',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-03-27T19:27:00.000Z',
#    'ID': 28,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'covid19@lifearc.org',
#    'Organization': 'LifeArc',
#    'Total Budget (USD, Estimated)': 12466150,
#    'Organization Type': 'Research Institute'},
#   'createdTime': '2020-03-28T00:01:57.000Z'},
#  {'id': 'rec9z1xsujTHqoBfZ',
#   'fields': {'Name': 'Code Life Ventilator Challenge',
#    'Categories': ['recWQc2ta6gw3MFoO'],
#    'Organization Logo': [{'id': 'attTl010i266XUySs',
#      'url': 'https://dl.airtable.com/.attachments/7364bfba81d40b78040158d004b7d893/9fe538c2/download14.png',
#      'filename': 'download (14).png',
#      'size': 6155,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/f3ba7cb367bec665eaa6ff84a4822685/b6227f00',
#        'width': 85,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/db623dd5d258bcebc1b9aef92e9e7870/d5a8d247',
#        'width': 345,
#        'height': 146},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/786249fb67e4489f9d782448c3e52d1c/3dc09669',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-03-31',
#    'Official URL': 'https://www.agorize.com/en/challenges/code-life-challenge?lang=en',
#    'Issued': '2020-03-18',
#    'Issuance country': ['recO5m8GWLAC3mOOo'],
#    'Budget (Detail)': '142,617',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-03-28T18:36:00.000Z',
#    'ID': 38,
#    'Input by': 'Natali Souza',
#    'Organization': 'Montreal General Hospital Foundation',
#    'Total Budget (USD, Estimated)': 142617,
#    'Organization Type': 'Non-profit '},
#   'createdTime': '2020-03-29T13:51:43.000Z'},
#  {'id': 'recAeYQdRwPvMsREC',
#   'fields': {'Name': 'COVID-19 I-CO Fund Call for Proposals',
#    'Categories': ['rec0XJtb00Csoh3CT',
#     'rec10jFunep6i7LND',
#     'recWQc2ta6gw3MFoO',
#     'recx3OdNvu7vqHLrL'],
#    'Organization Logo': [{'id': 'attvY0QXwc1ocw84c',
#      'url': 'https://dl.airtable.com/.attachments/c0f79450b688b2abbb44b8b8f54c6143/260604e1/icofund-icnon-single-plus-ikp-icons.png',
#      'filename': 'icofund-icnon-single-plus-ikp-icons.png',
#      'size': 51955,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/856408740d95d7bf5609d168a9724105/a9d02c81',
#        'width': 87,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/24eaedf302d204e4ea579eabbc610818/ba5fbb59',
#        'width': 569,
#        'height': 235},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/25c7301fb1a6645a712459c8e60b5c41/b6b03cca',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-04-03',
#    'Official URL': 'https://ikpeden.com/funding/',
#    'Issued': '2020-03-01',
#    'Issuance country': ['rectx8xceFl3DDiVX'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'National',
#    'Entry Timestamp': '2020-03-31T16:03:00.000Z',
#    'Notes': 'https://drive.google.com/file/d/1DXP1BXVbQo1NGBtk5L5ZnRhGo-IxdKAS/view',
#    'ID': 49,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'apex@ikpknowledgepark.com or call +91-87906-72424 / +91-79896-46563',
#    'Organization': 'IKP Knowledge Park and IKP Trust',
#    'Organization Type': 'Private Company'},
#   'createdTime': '2020-04-01T18:04:47.000Z'},
#  {'id': 'recAwOtVll446XuWb',
#   'fields': {'Name': 'Covid-19 fast track',
#    'Categories': ['recWQc2ta6gw3MFoO',
#     'rec0XJtb00Csoh3CT',
#     'rec10jFunep6i7LND',
#     'recIq8hBU4RbxR42y',
#     'recQCO0OJC04Cg0aZ',
#     'recI5ZRtTNRaZm80W',
#     'rec9GaNTHXsfeq8UH',
#     'recj4TMhOU9ieeweU',
#     'recMZ54t74nfcctvr',
#     'recx3OdNvu7vqHLrL',
#     'recc8FTZUD8j9obGa',
#     'recONh9EvkVDp2zKQ'],
#    'Organization Logo': [{'id': 'atty9fGhRuttcDrBJ',
#      'url': 'https://dl.airtable.com/.attachments/19293b2e77e07b2fb57b5f8997f952fc/86e36a73/0.png',
#      'filename': '0.png',
#      'size': 24937,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/2a4daa508958b93e9cbabafd45103114/8046f95a',
#        'width': 36,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/2cf3cb0241bdedbea122abfc562bea20/a23e0239',
#        'width': 200,
#        'height': 200},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/e9834c8c59f3082fa53eb462cbeacd4a/324b6c90',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-04-28',
#    'Official URL': 'https://www.gov.uk/government/publications/defence-and-security-accelerator-dasa-open-call-for-innovation/open-call-competition-document#Covid-19',
#    'Issued': '2020-03-01',
#    'Issuance country': ['recVHZtLbdvDmSSYd'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-04-20T15:19:00.000Z',
#    'ID': 104,
#    'Input by': 'Natali Souza',
#    'Organization': 'Defence and Security Accelerator ',
#    'Total Budget (USD, Estimated)': 0,
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-04-26T00:41:44.000Z'},
#  {'id': 'recBWRyYmaUqmtHqO',
#   'fields': {'Name': 'Call for the Innovation Program in Jalisco 2020 - Challenge Jalisco COVID-19',
#    'Categories': ['recIq8hBU4RbxR42y',
#     'rec0XJtb00Csoh3CT',
#     'recj4TMhOU9ieeweU',
#     'recI5ZRtTNRaZm80W',
#     'rec10jFunep6i7LND',
#     'recWQc2ta6gw3MFoO',
#     'recMZ54t74nfcctvr'],
#    'Organization Logo': [{'id': 'attKxeBFEMZycTqTn',
#      'url': 'https://dl.airtable.com/.attachments/f4f3e37f787808b3c29f1e39ba637a0c/c1d3dac8/Coecytjal.png',
#      'filename': 'Coecytjal.png',
#      'size': 38031,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/92a785fb6b1e429cff4cbfaeed675ae1/97e2dce2',
#        'width': 110,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/e4fe4e5d08f27cdcb538aa37a7c197c6/0f0c93e0',
#        'width': 1022,
#        'height': 333},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/ca2d7fa1980cc1459ca39d5583291459/fadf6c05',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-04-22',
#    'Official URL': 'http://www.coecytjal.org.mx/Plataforma/app/index.html?fbclid=IwAR3To5HQOPwgQb-cJZGj0vFugMBClnypeEUDNNt57G2UVvDQvIjVG_Lgrqc#/COVID19',
#    'Issued': '2020-04-03',
#    'Issuance country': ['recu9x8his8P2KnCL'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'National',
#    'Entry Timestamp': '2020-04-10T14:38:00.000Z',
#    'Notes': 'http://www.coecytjal.org.mx/Plataforma/app/views/2020/COVID19/Convocatoria%20PROINNJAL-COVID%202020%20VF.pdf',
#    'ID': 82,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'david.valle@coecytjal.org.mx, manuel.delatorre@coecytjal.org.mx, mauricio.espinosa@jalisco.gob.mx ',
#    'Organization': 'Consejo Estatal de Ciencia y Tecnología de Jalisco',
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-04-12T15:04:56.000Z'},
#  {'id': 'recDAeTZv2xiIr5IL',
#   'fields': {'Name': 'Call for rapid response to COVID-19 in Panama',
#    'Categories': ['rec0XJtb00Csoh3CT',
#     'rec9GaNTHXsfeq8UH',
#     'recIq8hBU4RbxR42y',
#     'recEwfTiy7301HPv3'],
#    'Organization Logo': [{'id': 'attOD72GiyOGJwD3J',
#      'url': 'https://dl.airtable.com/.attachments/a92a63d5098618759c895b26409c222d/346b5832/logoSenacyt827x208.jpg',
#      'filename': 'logoSenacyt827x208.jpg',
#      'size': 39829,
#      'type': 'image/jpeg',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/5fe0c30f0c61c7da87180adb6c6c6ae3/03cbe585',
#        'width': 143,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/8ccd0dc7a7467c5ac8adc991004363da/3ff12879',
#        'width': 827,
#        'height': 208},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/d58a3071a48e0531988bc016b206a097/da2171e8',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-03-27',
#    'Official URL': 'https://www.senacyt.gob.pa/convocatoria-de-respuesta-rapida-al-covid-19-en-panama/',
#    'Issued': '2020-03-20',
#    'Issuance country': ['recNjRjraKVnsyLRC'],
#    'Budget (Detail)': '201,889',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-03-26T17:11:00.000Z',
#    'Notes': 'https://www.senacyt.gob.pa/wp-content/uploads/2020/03/2-Anuncio-COVID19-IDi-Resolucion-No.-104.pdf\nOther category: Prevention, AI',
#    'ID': 10,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'covid19@senacyt.gob.pa, +507 517-0014 ',
#    'Organization': 'Secretaría Nacional de Ciencia, Tecnología e Innovación ',
#    'Total Budget (USD, Estimated)': 201889,
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-03-26T17:11:44.000Z'},
#  {'id': 'recDPORleeoJsEGtK',
#   'fields': {'Name': 'Covid-19 Resilience Innovation Project Support',
#    'Categories': ['rec10jFunep6i7LND',
#     'recMZ54t74nfcctvr',
#     'recWQc2ta6gw3MFoO'],
#    'Organization Logo': [{'id': 'attUEGfJwGiqxuXJf',
#      'url': 'https://dl.airtable.com/.attachments/9e886e0e307f1335d298d8d57cfad437/c18fae1f/logo-en.png',
#      'filename': 'logo-en.png',
#      'size': 10774,
#      'type': 'image/png',
#      'thumbnails': {'small': {'url': 'https://dl.airtable.com/.attachmentThumbnails/e495a020a4e983af29f6b5c8eb7610fb/63a9f364',
#        'width': 156,
#        'height': 36},
#       'large': {'url': 'https://dl.airtable.com/.attachmentThumbnails/785282b98468487574702fe2983f6e04/a3a90bd9',
#        'width': 330,
#        'height': 76},
#       'full': {'url': 'https://dl.airtable.com/.attachmentThumbnails/eec29cc7e977ddccb5ff8c7e5724b780/131b4595',
#        'width': 3000,
#        'height': 3000}}}],
#    'Deadline': '2020-12-31',
#    'Official URL': 'https://businesswales.gov.wales/expertisewales/covid-19-resilience-innovation-project-support',
#    'Issued': '2020-03-01',
#    'Issuance country': ['recGdqpTXWbgK48CN'],
#    'Budget (Detail)': 'Undisclosed',
#    'Bid Type': 'International ',
#    'Entry Timestamp': '2020-04-02T10:31:00.000Z',
#    'ID': 53,
#    'Input by': 'Natali Souza',
#    'Organizer Contact': 'To get started you can contact our team on 03000 250 243 or Email SMARTCymru@gov.wales',
#    'Organization': 'Expertise Wales',
#    'Organization Type': 'Government Entity'},
#   'createdTime': '2020-04-04T16:41:37.000Z'}]

# %% [markdown]
# # Step: 3 Converting category id's into names

# %%
id_list = []
for record in categories_records:
    id_list.append((record['id']))
    #print(record['fields'])
    
id_list
# Out:
# ['rec0XJtb00Csoh3CT',
#  'rec10jFunep6i7LND',
#  'rec8w3NFLTMjwh4Vr',
#  'rec9GaNTHXsfeq8UH',
#  'recEwfTiy7301HPv3',
#  'recI5ZRtTNRaZm80W',
#  'recIq8hBU4RbxR42y',
#  'recMZ54t74nfcctvr',
#  'recONh9EvkVDp2zKQ',
#  'recQCO0OJC04Cg0aZ',
#  'recWQc2ta6gw3MFoO',
#  'recc8FTZUD8j9obGa',
#  'recj4TMhOU9ieeweU',
#  'recuZ68TmTG5jWEvg',
#  'recx3OdNvu7vqHLrL']

# %%
#List names of each category ID
import pandas as pd
df_tenders = pd.DataFrame.from_records((r['fields'] for r in tenders_records))
df_categories = pd.DataFrame.from_records((r['fields'] for r in categories_records))
df_categories['ID'] = id_list

df_categories_names = df_categories[['ID','Name']].copy()
df_tendername = df_tenders[['Name','Categories']].copy()


#df_tenders.head()
#df_tendername.head()
df_categories_names
# Out:
#                    ID  \
# 0   rec0XJtb00Csoh3CT
# 1   rec10jFunep6i7LND
# 2   rec8w3NFLTMjwh4Vr
# 3   rec9GaNTHXsfeq8UH
# 4   recEwfTiy7301HPv3
# 5   recI5ZRtTNRaZm80W
# 6   recIq8hBU4RbxR42y
# 7   recMZ54t74nfcctvr
# 8   recONh9EvkVDp2zKQ
# 9   recQCO0OJC04Cg0aZ
# 10  recWQc2ta6gw3MFoO
# 11  recc8FTZUD8j9obGa
# 12  recj4TMhOU9ieeweU
# 13  recuZ68TmTG5jWEvg
# 14  recx3OdNvu7vqHLrL
#
#                                                                                        Name
# 0   Diagnosis, Screening & Detection of Virus
# 1   Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement)
# 2   Prevention and Education
# 3   Medication: Antiviral, Therapeutics, Vaccine (and research thereof)
# 4   Other (Specify in Comments)
# 5   Monitoring, Alerts & Communication
# 6   Algorithms, Artificial Intelligence & Prediction
# 7   Decontamination
# 8   Remote Work
# 9   Crisis Management Tools (Logistics, Human Resources, ..)
# 10  Medical Care Support
# 11  Quarantine and Confined Life
# 12  Prevention and Education
# 13  Field hospital (Temporary Hospitals) solutions
# 14  Remote healthcare

# %%
#List category of all tenders
df_tenders = pd.DataFrame.from_records((r['fields'] for r in tenders_records))
df_tendername = df_tenders[['Name','Categories']].copy()
df_categories = pd.DataFrame.from_records((r['fields'] for r in categories_records))

df_categories['ID'] = id_list
df_categories_names = df_categories[['ID','Name']].copy()

new_x = df_tendername.apply(lambda x: pd.Series(x['Categories']),axis=1).stack().reset_index(level=1, drop=True)
new_x.name = 'Category'
new_df = df_tendername.drop(['Categories'],axis=1).join(new_x)

#Function to convert category id's to names
def id_converter(row):
    row['Category'] = df_categories_names.loc[df_categories['ID'] == row['Category'], 'Name'].values[0]
    return row
    

new_df.apply (lambda row: id_converter(row), axis=1)

#Sorting Table frormat to 
df_categorynames = new_df.groupby('Name').agg({'Category': ', '.join}).reset_index()
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)


df_categorynames
# Out:
#                                                                                                                   Name  \
# 0   AMable Call for Solution Ideas to COVID-19 challenges
# 1   Botswana Innovation Fund Call for Applications
# 2   COVID-19 Extraordinary Call for Proposals 2020
# 3   COVID-19 I-CO Fund Call for Proposals
# 4   COVID-19 Response Team
# 5   COVID-19 Solutions in Digital Health
# 6   Call for Proposals for Projects in the Development, Piloting and Demonstration stages to cope with the Coronavirus
# 7   Call for innovations who can offer a response to the COVID-19 pandemic
# 8   Call for rapid response to COVID-19 in Panama
# 9   Call for the Innovation Program in Jalisco 2020 - Challenge Jalisco COVID-19
# 10  CcHUB: Funding and Design Support for COVID-19 Projects
# 11  Challenge Covid-19
# 12  Code Life Ventilator Challenge
# 13  Coronavirus (Covid-19) Therapeutics: £10 Million Call For Rapid Deployment
# 14  Covid-19 Resilience Innovation Project Support
# 15  Covid-19 fast track
# 16  Invitation of technology proposals for fighting COVID 19
# 17  Mining companies unite to face the challenges of Covid-19 together
# 18  Santa Catarina's Business Fund for Articulated Reaction Against Coronavirus
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Category
# 0   Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Medical Care Support
# 1   Algorithms, Artificial Intelligence & Prediction, Crisis Management Tools (Logistics, Human Resources, ..) , Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Prevention and Education , Diagnosis, Screening & Detection of Virus, Monitoring, Alerts & Communication , Medical Care Support
# 2   Remote healthcare, Algorithms, Artificial Intelligence & Prediction, Prevention and Education , Remote Work, Medical Care Support, Monitoring, Alerts & Communication , Crisis Management Tools (Logistics, Human Resources, ..)
# 3   Diagnosis, Screening & Detection of Virus, Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Medical Care Support, Remote healthcare
# 4   Algorithms, Artificial Intelligence & Prediction, Diagnosis, Screening & Detection of Virus, Prevention and Education , Crisis Management Tools (Logistics, Human Resources, ..) , Monitoring, Alerts & Communication , Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Medical Care Support, Remote healthcare, Medication: Antiviral, Therapeutics, Vaccine (and research thereof), Remote Work, Decontamination, Quarantine and Confined Life
# 5   Algorithms, Artificial Intelligence & Prediction, Medical Care Support, Diagnosis, Screening & Detection of Virus, Medication: Antiviral, Therapeutics, Vaccine (and research thereof), Crisis Management Tools (Logistics, Human Resources, ..)
# 6   Diagnosis, Screening & Detection of Virus, Prevention and Education , Remote healthcare, Medication: Antiviral, Therapeutics, Vaccine (and research thereof), Medical Care Support, Monitoring, Alerts & Communication , Crisis Management Tools (Logistics, Human Resources, ..) , Quarantine and Confined Life
# 7   Medical Care Support, Algorithms, Artificial Intelligence & Prediction, Diagnosis, Screening & Detection of Virus, Medication: Antiviral, Therapeutics, Vaccine (and research thereof), Other (Specify in Comments)
# 8   Diagnosis, Screening & Detection of Virus, Medication: Antiviral, Therapeutics, Vaccine (and research thereof), Algorithms, Artificial Intelligence & Prediction, Other (Specify in Comments)
# 9   Algorithms, Artificial Intelligence & Prediction, Diagnosis, Screening & Detection of Virus, Prevention and Education , Monitoring, Alerts & Communication , Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Medical Care Support, Decontamination
# 10  Monitoring, Alerts & Communication , Medical Care Support, Prevention and Education , Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Crisis Management Tools (Logistics, Human Resources, ..)
# 11  Crisis Management Tools (Logistics, Human Resources, ..) , Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Prevention and Education
# 12  Medical Care Support
# 13  Medication: Antiviral, Therapeutics, Vaccine (and research thereof)
# 14  Medical Care Support, Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Decontamination, Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Decontamination, Medical Care Support
# 15  Medical Care Support, Diagnosis, Screening & Detection of Virus, Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Algorithms, Artificial Intelligence & Prediction, Crisis Management Tools (Logistics, Human Resources, ..) , Monitoring, Alerts & Communication , Medication: Antiviral, Therapeutics, Vaccine (and research thereof), Prevention and Education , Decontamination, Remote healthcare, Quarantine and Confined Life, Remote Work
# 16  Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Diagnosis, Screening & Detection of Virus, Algorithms, Artificial Intelligence & Prediction, Decontamination, Monitoring, Alerts & Communication
# 17  Algorithms, Artificial Intelligence & Prediction, Diagnosis, Screening & Detection of Virus, Remote healthcare, Decontamination, Monitoring, Alerts & Communication , Field hospital (Temporary Hospitals) solutions, Prevention and Education , Quarantine and Confined Life, Medical Care Support
# 18  Commodity Medical Supply (Masks, Ventilators, Gloves, Sanitizer, Protective Equipement), Diagnosis, Screening & Detection of Virus, Decontamination, Crisis Management Tools (Logistics, Human Resources, ..) , Remote Work, Prevention and Education , Medical Care Support

# %% [markdown]
# # Original Data Analytics by Chloe Ji

# %%
#find current path 
current_path = os.path.abspath('')

#Make a charts directory inside of it
#then populate with data files

# %%
import pandas as pd
import re 
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator 
import os 
import numpy as np
import math 
 

def read_file(filename):
    df= list()
    for file in filename:
        if file !='.ipynb_checkpoints': 
            print(file)
            df.append(pd.read_csv(os.path.join('charts/',file)))
    return df 
  

def trans_cats_tenders(tender_file):
    
    marker = ",!$%^&,"
    data= tender['Categories'][0]
    PATTERN= re.compile(r'''((?:[^",']|"[^"]*"|'[^']*')+)''')
    tender_file['Categories']= tender_file['Categories'].apply(lambda row: [r.replace(marker[1:-1],'') for r in PATTERN.split(row.replace(',,', marker))[1::2]])
    tender_file['rowsPos']=tender_file.index 
    tender_file['continent']= tender_file['Issuance country'].map(
        {'Argentina':'South America','Australia':'Oceania',
         'Bangladesh':'Asia','Brazil':'South America',
         'Canada':'North America','Colombia':'South America',
         'Denmark':'Europe','European Union ':'Europe','France':'Europe',
         'India':'Asia','Ireland':'Europe','Israel':'Asia','Lebanon':'Asia',
         'Nigeria':'Africa','Pakistan':'Asia','Panama':'North America','Portugal':'Europe',
         'Spain':'Europe','Sweden':'Europe','United Kingdom':'Europe',
         'United States':'North America','Worldwide':'Other'}) 
    
    return tender_file 

def trans_solution_table(solution_file):
    solution_file['Continent']= solution_file['Company Location'].map(
        {'Canada':'North America','Singapore':'Asia',
         'United States':'North America','Korea':'Asia',
         'France':'Europe','Cyprus':'Europe','Switzerland':'Europe',
         'Hong Kong SAR':'Asia','Taiwan':'Asia','Egypt':'Africa','India':'Asia'})
    
    return solution_file
    
def tender_cats_table(file):
    tender_cats=file['Categories'].apply(pd.Series).reset_index().melt(id_vars='index').dropna()[['index', 'value']].set_index('index')
    tender_cats['rowsPos']=tender_cats.index 
    
    return tender_cats 

def all_cats(tender_file, cats_file):
    df_tender=cats_file.merge(tender_file, on='rowsPos', how='left')
    
    return df_tender

# %%
print(tender)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-fab1cd59655e> in <module>
# ----> 1 print(tender)
#
# NameError: name 'tender' is not defined

# %%
filedir= os.listdir('charts/')
cats, solution, tender= read_file(filedir)
tender=trans_cats_tenders(tender)  
tender_cats=tender_cats_table(tender) 
df_tender = all_cats(tender, tender_cats) 
solution_table= trans_solution_table(solution)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-47-ed96b10198d4> in <module>
# ----> 1 filedir= os.listdir('charts/')
#       2 cats, solution, tender= read_file(filedir)
#       3 tender=trans_cats_tenders(tender)
#       4 tender_cats=tender_cats_table(tender)
#       5 df_tender = all_cats(tender, tender_cats)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'charts/'

# %%
tendersNum=tender.groupby('continent', as_index= False)['Organization'].count() 
tendersNum_sort=tendersNum.sort_values('Organization', ascending= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-86a51f940b11> in <module>
# ----> 1 tendersNum=tender.groupby('continent', as_index= False)['Organization'].count()
#       2 tendersNum_sort=tendersNum.sort_values('Organization', ascending= False)
#
# NameError: name 'tender' is not defined

# %%
tendersNum_sort

# %%
def plot_basic(file, title, ylabel, xlabel):
    
    plt.style.use('ggplot') 
    fig, ax = plt.subplots(
        nrows = 1,
        figsize = (16,10),
        dpi = 80, 
        facecolor = 'w', 
        edgecolor = 'k')
    
    tenderNum = file[file.columns[0]] 
    continent = file[file.columns[1]] 
    
    ax.tick_params(axis='both', which='major', labelsize = 16)  
    ax.yaxis.set_major_locator(MaxNLocator(integer = True))
    ax.get_xaxis().get_major_formatter().set_useOffset(False)
    ax.set_title(title, pad = 28,fontsize = 22, ha="center") 
    plt.axis(aspect='equal')
    ax.set_xticklabels(tenderNum)
    plt.ylabel(ylabel,fontsize = 16) 
    plt.xlabel(xlabel,fontsize = 16)  
    
    for tick in ax.get_xticklabels():
        tick.set_rotation(45)
        
    for i, v in enumerate(continent):
        ax.text(i+0.1, v+ 0.3, 
                str(v), 
                color = 'slategray',
                size = 12)
    
    plt.bar(tenderNum, continent, color='#28aae3', width=0.6, align='center')

    
plot_basic(tendersNum_sort, 
           'Refrenced Tenders on Covidtenders.org, per continent',
           'Number of Tenders', 
           'Continent')

# %%
solution_cats = solution.groupby('Continent')['Solution Name'].count()
solution_cats = pd.DataFrame(solution_cats)
solution_cats = solution_cats.reset_index() 
solution_cats

# %%
def plot_solution(file, title):
    
    fig,ax = plt.subplots(
        nrows = 1,
        figsize = (16,10),
        dpi = 80, 
        facecolor = 'w', 
        edgecolor = 'k')
    
    continent = file[file.columns[0]] 
    counts = file[file.columns[1]]  
    explode = (0, 0.1, 0, 0)
    colors = ['#08018d','#27abe3','#08018d','#544741']
     
    def abs_value(val):
        a  = np.round(val/100.*counts.sum(), 0)
        a ='{0:,.0f}'.format(a)
        return a
    
    patches, texts, autotexts= ax.pie(counts, 
                                      explode = explode,
                                      colors = colors,
                                      labels = continent, 
                                      autopct = abs_value,
                                      startangle = 90,
                                      shadow = True)
    centre_circle = plt.Circle((0,0),0.68, fc = 'white')  
    fig.gca().add_artist(centre_circle)
    
    plt.title(title, fontsize = 20, ha = "center")
    for text in texts:
        text.set_color('black')
    for text in texts:
        text.set_fontsize(16)
        
    for autotext in autotexts:
        autotext.set_color('black')
    for autotext in autotexts:
        autotext.set_fontsize(16) 

    plt.tight_layout() 
    
    
ax = plot_solution(solution_cats, 'Submitted Solutions on Covidtenders.org Per Continent')

# %%
tendersCount_cats = pd.DataFrame(cats.groupby('Name')['Tenders Count'].sum()) 
submittedCount_cats = pd.DataFrame(cats.groupby('Name')['Submitted Tenders Count'].sum()) 
submittedCount_cats = submittedCount_cats.reset_index()

# %%
submittedCount_cats

# %%
totalCats = submittedCount_cats.merge(tendersCount_cats,on='Name', how='left')
totalCats

# %%
totalCats.loc[3,'Name'] = "Crisis Management Tool"
totalCats.loc[2,'Name'] = "Commodity Medical Supply"
totalCats.loc[6,'Name'] = "Field hospital"
totalCats.loc[8,'Name'] = "Medication: Antiviral, Therapeutics, Vaccine"

# %%
totalCats

# %%
def plot_cats(file,title, xlabel, ylabel):
    
    ax = file.plot('Name',[1,2], 
                       kind = 'bar',
                       ylim = (0, 46), 
                       title = title,
                       figsize = (16,10), 
                       width = 0.8,
                       stacked = False,
                      fontsize = 14)   

    for p in ax.patches:
            ax.annotate(np.round(p.get_height(), decimals=0).astype(np.int64), 
                        (p.get_x() + p.get_width()/2., p.get_height()), 
                        ha = 'center', va = 'center', 
                        xytext = (2, 10), 
                        textcoords='offset points',
                        color = 'slategray')

    ax.set_xlabel(xlabel, fontsize = 16)
    ax.set_ylabel(ylabel,fontsize = 16) 

plot_cats(totalCats,'TENDER and SUBMITTED TENDER SOLUTIONS PER CATEGORY',"Tender Solution","Solution Numbers")

# %%
df_tender['Budget'] = df_tender['Budget (USD)'].map(
    {'10,812,000':10812000, '177,000,000':177000000, '49,600,000':49600000, 
     '1,986,060':1986060,'26,122,800':26122800, '1,642,800':1642800, 
     'Undisclosed':0, '609,790':609790, '142.617':142617,'1,116,849':1116849, 
     '49.203,00 max per project':49203, '2,000,000':2000000,'4.738.797,00':4738797, 
     'Up to 54,030,00 per project ':54030,'100,000 per solution':100000, 
     '24,453,100':24453100, '103,962,00':103962, '658,002':658002,'6,385,037':6385037, 
     '3,985,414':3985414, '- Undisclosed':0,'Between 54.267,00 and 542,464,000 per project':54267, 
     '12,466,150':12466150,'201,889':201889, '198,281.56':198281.56, '7,459,700':7459700, 
     '50,000':50000,'Up to $1M per project':1000000, 'A minimum of $250,000':250000,
     '10,000 per solution':10000, '163,412':163412, 'Up to $100,000 per program':100000,
     '5,000,000':5000000, '1,000,000':1000000, 'Up to $50,000 per project':50000})

# %%
budget_by_cats = df_tender.groupby(['value'], as_index = False)['Budget'].sum() 
budget_by_cats['value']

# %%
budget_by_cats.loc[0,'value'] = 'Alerts, Communication' 
budget_by_cats.loc[1,'value'] = 'Algorithms, AI and Prediction'
budget_by_cats.loc[2,'value'] = 'Commodity Medical Supply'
budget_by_cats.loc[3,'value'] = 'Crisis Management (HR, IT, Logistics)'
budget_by_cats.loc[4,'value'] = 'Diagnosis, Detection and Screening of Virus'
budget_by_cats.loc[5,'value'] = 'Medication: Antiviral, Therapeutics, Vaccine'
budget_by_cats.loc[7,'value'] = 'Field hospital' 
budget_by_cats.loc[8,'value'] = 'Support to Medical Care'
budget_by_cats.loc[9,'value'] = 'Other'

# %%
cats_sorted = budget_by_cats.sort_values('Budget', ascending = True) 
cats_sorted = pd.DataFrame(cats_sorted) 
cats_sorted['Budget'] = cats_sorted['Budget'].astype(int) 
cats_sorted

# %%
def plot(file, title, ylabel, xlabel):
    
    fig,ax = plt.subplots(
        nrows = 1,
        figsize = (18,16),
        dpi = 80, 
        facecolor = 'w', 
        edgecolor = 'k')
    
    cats = file[file.columns[0]] 
    budget = file[file.columns[1]] 
    ax.tick_params(axis='both', which='major', labelsize=20)  
    csfont = {'fontname':'sans-serif'}

    ax.get_xaxis().get_major_formatter().set_useOffset(False)
    ax.set_title(title, pad=28,fontsize=32, ha="center",**csfont) 
    plt.axis(aspect='equal')
    ax.set_xlim(0, 400000000)
    ax.set_xticklabels(np.arange(0, 400000000,50000000)) 
    plt.ylabel(ylabel,fontsize=28) 
    plt.xlabel(xlabel,fontsize=28) 
    plt.barh(cats, budget, color='#544741',align="center",animated=0.8)
    
    def roundNum(n, decimals=0):
        multiplier = 100 ** decimals
        
        return math.ceil(n * multiplier) / multiplier

    for i, v in enumerate(budget):
        style = dict(size=12, color='#544741')
        ax.text(v, i-0.1, '{0:,.0f}'.format(roundNum(v, -2)), 
                va='baseline',
                ha='left',
                **style)
    plt.show()

# %%
plot(cats_sorted, 
     'COVID Institutional Tenders: Total Budget per Category (World)',
     'Category',
     'Cumulative Budget (USD) of Tenders')
